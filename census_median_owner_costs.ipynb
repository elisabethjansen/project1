# %%
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a file path
census_data = pd.read_csv("Resources/census_data_clean_monthly_owner_costs.csv")

# Read in the data. 
census_data.head()
# Out:
#    Owner_Occupied_Units  Owner_White_alone  \
# 0                3283.0             2604.0
# 1                9528.0             8298.0
# 2               11118.0             9141.0
# 3                1470.0              717.0
# 4                6758.0             5612.0
#
#    Owner_Black_African_American_alone  \
# 0                                13.0
# 1                               239.0
# 2                               394.0
# 3                                 6.0
# 4                               127.0
#
#    Owner_American_Indian_Alaska_Native_alone  Owner_Asian_alone  \
# 0                                        6.0                0.0
# 1                                        0.0                0.0
# 2                                       22.0               26.0
# 3                                       10.0                0.0
# 4                                        0.0                0.0
#
#    Owner_Native_Hawaiian_Other_Pacific_Islander_alone  \
# ...

# %%
# Median monthly owner cost over time
# Group by year and calculate the mean owner-occupancy rate for each year
median_owner_rent_by_year = census_data.groupby('year')['Median_Monthly_Owner_Costs'].median()
median_owner_rent_by_year
# Out:
# year
# 2019    1233.5
# 2020    1259.0
# 2021    1322.0
# 2022    1426.0
# Name: Median_Monthly_Owner_Costs, dtype: float64
