# %%
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a file path
census_data = pd.read_csv("Resources/census_data_clean_medgross.csv")

# Read in the data. 
census_data.head()
# Out:
#    Owner_Occupied_Units  Owner_White_alone  \
# 0                   265                265
# 1                   418                398
# 2                   352                352
# 3                   333                333
# 4                     7                  7
#
#    Owner_Black_African_American_alone  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#    Owner_American_Indian_Alaska_Native_alone  Owner_Asian_alone  \
# 0                                          0                  0
# 1                                          3                  0
# 2                                          0                  0
# 3                                          0                  0
# 4                                          0                  0
#
#    Owner_Native_Hawaiian_Other_Pacific_Islander_alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Owner_Some_other_race_alone  Owner_Two_or_more_races  \
# 0                            0                        0
# 1                            8                        9
# 2                            0                        0
# 3                            0                        0
# 4                            0                        0
#
#    Owner_White_no_Hispanic_or_Latino  Owner_Hispanic_Latino  ...  \
# 0                                265                      0  ...
# 1                                398                     11  ...
# 2                                344                      8  ...
# 3                                333                      0  ...
# 4                                  7                      0  ...
#
#    Black_African_American  American_Indian_Alaska_Native  Asian  \
# 0                       0                              0      0
# 1                       0                              3      0
# 2                      21                              0      0
# 3                      19                              0      0
# 4                       0                              0      0
#
#    Native_Hawaiian_Other_Pacific_Islander  Other_Race  Two_More_Races  \
# 0                                       0           0               0
# 1                                       0          16              16
# 2                                       0           0               0
# 3                                       0           0               0
# 4                                       0           0               0
#
#    Count_Inds_Income_Past_12_Mos_<_Pov_Level  state  Zip_code  year
# 0                                        771    NaN     40771  2020
# 1                                        166    NaN     73547  2020
# 2                                        156    NaN     58788  2021
# 3                                        118    NaN     58788  2022
# 4                                          8   30.0     59025  2019
#
# [5 rows x 34 columns]

# %%
# Median household income over time
# Group by year and calculate the mean owner-occupancy rate for each year
median_gross_rent = census_data.groupby('year')['Median_Gross_Rent'].median()
median_gross_rent
# Out:
# year
# 2019    814.0
# 2020    831.0
# 2021    871.0
# 2022    944.0
# Name: Median_Gross_Rent, dtype: float64

# %%
# Median household income over time
# Median gross rent over time
# Median monthly owner cost over time
